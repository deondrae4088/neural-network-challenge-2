# %% [markdown]
# <a href="https://colab.research.google.com/github/deondrae4088/neural-network-challenge-2/blob/main/attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
selected_columns = [
    'Age', 'BusinessTravel', 'DistanceFromHome', 'Education',
    'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement',
    'JobLevel', 'JobSatisfaction', 'MaritalStatus'
]

# Create X_df using your selected columns
X_df = attrition_df[selected_columns]

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                         int64
# BusinessTravel             object
# DistanceFromHome            int64
# Education                   int64
# EnvironmentSatisfaction     int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MaritalStatus              object
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=42)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_numeric = pd.get_dummies(X_df)
# Display the first few rows of the transformed data
X_numeric.head()
# Out:
#    Age  DistanceFromHome  Education  EnvironmentSatisfaction  HourlyRate  \
# 0   41                 1          2                        2          94
# 1   49                 8          1                        3          61
# 2   37                 2          2                        4          92
# 3   33                 3          4                        4          56
# 4   27                 2          1                        1          40
#
#    JobInvolvement  JobLevel  JobSatisfaction  BusinessTravel_Non-Travel  \
# 0               3         2                4                      False
# 1               2         2                2                      False
# 2               2         1                3                      False
# 3               3         1                3                      False
# 4               3         1                2                      False
#
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                             False                          True
# 1                              True                         False
# 2                             False                          True
# 3                              True                         False
# 4                             False                          True
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 0                   False                  False                  True
# 1                   False                   True                 False
# 2                   False                  False                  True
# 3                   False                   True                 False
# 4                   False                   True                 False

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder for the Department column
encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
encoder.fit(y_train[['Department']])


# Create two new variables by applying the encoder
# to the training and testing data
y_train_encoded = encoder.transform(y_train[['Department']])
y_test_encoded = encoder.transform(y_test[['Department']])

# %%
# Create a OneHotEncoder for the Attrition column
attrition_encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
attrition_encoder.fit(y_train[['Attrition']])


# Create two new variables by applying the encoder
# to the training and testing data
y_train_attrition_encoded = attrition_encoder.transform(y_train[['Attrition']])
y_test_attrition_encoded = attrition_encoder.transform(y_test[['Attrition']])

# %% [markdown]
# ## Part 2: Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data.
input_shape = X_train_scaled.shape[1]

# Create the input layer
input_layer = layers.Input(shape=(input_shape,))

# Create at least two shared layers
shared_layer_1 = layers.Dense(128, activation='relu')(input_layer)
shared_layer_2 = layers.Dense(64, activation='relu')(shared_layer_1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
department_hidden_layer = layers.Dense(32, activation='relu')(shared_layer_2)

# Create the output layer
department_output_layer = layers.Dense(y_train_encoded.shape[1], activation='softmax', name='department_output')(department_hidden_layer)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
attrition_hidden_layer = layers.Dense(32, activation='relu')(shared_layer_2)

# Create the output layer
attrition_output_layer = layers.Dense(y_train_attrition_encoded.shape[1], activation='softmax', name='attrition_output')(attrition_hidden_layer)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[department_output_layer, attrition_output_layer])

# Compile the model
model.compile(optimizer='adam',
              loss={'department_output':'categorical_crossentropy', 'attrition_output':'categorical_crossentropy'},
              metrics={'department_output': 'accuracy', 'attrition_output': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 14)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │          1,920 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          2,080 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 32)             │          2,080 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department_output (Dense) │ (None, 3)              │             99 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition_output (Dense)  │ (None, 2)              │             66 │ dense_3[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 14,501 (56.64 KB)
#  Trainable params: 14,501 (56.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
X_train_scaled,
{'department_output': y_train_encoded, 'attrition_output': y_train_attrition_encoded},
epochs=100,
batch_size=100,
validation_data=(X_test_scaled, {'department_output': y_test_encoded, 'attrition_output': y_test_attrition_encoded}),
verbose=1
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 41ms/step - attrition_output_accuracy: 0.4112 - attrition_output_loss: 0.7324 - department_output_accuracy: 0.5539 - department_output_loss: 0.9764 - loss: 1.7095 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.5310 - val_department_output_accuracy: 0.6667 - val_department_output_loss: 0.8041 - val_loss: 1.3356
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8429 - attrition_output_loss: 0.5050 - department_output_accuracy: 0.6662 - department_output_loss: 0.7993 - loss: 1.3042 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3971 - val_department_output_accuracy: 0.6667 - val_department_output_loss: 0.7711 - val_loss: 1.1697
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8274 - attrition_output_loss: 0.4497 - department_output_accuracy: 0.6468 - department_output_loss: 0.7716 - loss: 1.2214 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3740 - val_department_output_accuracy: 0.6701 - val_department_output_loss: 0.7822 - val_loss: 1.1578
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.8345 - attrition_output_loss: 0.4149 - department_output_accuracy: 0.6499 - department_output_loss: 0.7591 - loss: 1.1733 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3671 - val_department_output_accuracy: 0.6701 - val_department_output_loss: 0.7716 - val_loss: 1.1402
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8263 - attrition_output_loss: 0.4164 - department_output_accuracy: 0.6374 - department_output_loss: 0.7695 - loss: 1.1862 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3610 - val_department_output_accuracy: 0.6667 - val_department_output_loss: 0.7735 - val_loss: 1.1358
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.8375 - attrition_output_loss: 0.3992 - department_output_accuracy: 0.6560 - department_output_loss: 0.7278 - loss: 1.1269 - val_attrition_output_accuracy: 0.8776 - val_attrition_output_loss: 0.3540 - val_department_output_accuracy: 0.6701 - val_department_output_loss: 0.7777 - val_loss: 1.1330
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8534 - attrition_output_loss: 0.3696 - department_output_accuracy: 0.6681 - department_output_loss: 0.7295 - loss: 1.0991 - val_attrition_output_accuracy: 0.8776 - val_attrition_output_loss: 0.3518 - val_department_output_accuracy: 0.6701 - val_department_output_loss: 0.7778 - val_loss: 1.1310
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8626 - attrition_output_loss: 0.3658 - department_output_accuracy: 0.6526 - department_output_loss: 0.7241 - loss: 1.0902 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3557 - val_department_output_accuracy: 0.6667 - val_department_output_loss: 0.7810 - val_loss: 1.1379
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8696 - attrition_output_loss: 0.3556 - department_output_accuracy: 0.6418 - department_output_loss: 0.7269 - loss: 1.0825 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3506 - val_department_output_accuracy: 0.6667 - val_department_output_loss: 0.7834 - val_loss: 1.1354
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8488 - attrition_output_loss: 0.3772 - department_output_accuracy: 0.6581 - department_output_loss: 0.7118 - loss: 1.0887 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3515 - val_department_output_accuracy: 0.6531 - val_department_output_loss: 0.7840 - val_loss: 1.1368
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - attrition_output_accuracy: 0.8437 - attrition_output_loss: 0.3873 - department_output_accuracy: 0.6713 - department_output_loss: 0.7045 - loss: 1.0921 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3512 - val_department_output_accuracy: 0.6565 - val_department_output_loss: 0.7858 - val_loss: 1.1384
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8653 - attrition_output_loss: 0.3541 - department_output_accuracy: 0.6747 - department_output_loss: 0.6962 - loss: 1.0506 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3563 - val_department_output_accuracy: 0.6497 - val_department_output_loss: 0.7900 - val_loss: 1.1478
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - attrition_output_accuracy: 0.8668 - attrition_output_loss: 0.3500 - department_output_accuracy: 0.6668 - department_output_loss: 0.7035 - loss: 1.0537 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3522 - val_department_output_accuracy: 0.6361 - val_department_output_loss: 0.7951 - val_loss: 1.1487
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8649 - attrition_output_loss: 0.3444 - department_output_accuracy: 0.6927 - department_output_loss: 0.6715 - loss: 1.0162 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3553 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 0.8039 - val_loss: 1.1606
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8630 - attrition_output_loss: 0.3442 - department_output_accuracy: 0.6988 - department_output_loss: 0.6610 - loss: 1.0048 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3516 - val_department_output_accuracy: 0.6259 - val_department_output_loss: 0.8014 - val_loss: 1.1545
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8699 - attrition_output_loss: 0.3371 - department_output_accuracy: 0.7074 - department_output_loss: 0.6588 - loss: 0.9958 - val_attrition_output_accuracy: 0.8639 - val_attrition_output_loss: 0.3565 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 0.8105 - val_loss: 1.1685
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8770 - attrition_output_loss: 0.3265 - department_output_accuracy: 0.6984 - department_output_loss: 0.6624 - loss: 0.9888 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3573 - val_department_output_accuracy: 0.6259 - val_department_output_loss: 0.8163 - val_loss: 1.1752
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8831 - attrition_output_loss: 0.3166 - department_output_accuracy: 0.7154 - department_output_loss: 0.6275 - loss: 0.9438 - val_attrition_output_accuracy: 0.8707 - val_attrition_output_loss: 0.3572 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 0.8309 - val_loss: 1.1897
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8793 - attrition_output_loss: 0.3095 - department_output_accuracy: 0.7087 - department_output_loss: 0.6557 - loss: 0.9646 - val_attrition_output_accuracy: 0.8844 - val_attrition_output_loss: 0.3534 - val_department_output_accuracy: 0.6327 - val_department_output_loss: 0.8160 - val_loss: 1.1712
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - attrition_output_accuracy: 0.8802 - attrition_output_loss: 0.3075 - department_output_accuracy: 0.7295 - department_output_loss: 0.5882 - loss: 0.8952 - val_attrition_output_accuracy: 0.8605 - val_attrition_output_loss: 0.3655 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 0.8430 - val_loss: 1.2101
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - attrition_output_accuracy: 0.8745 - attrition_output_loss: 0.3170 - department_output_accuracy: 0.7079 - department_output_loss: 0.6105 - loss: 0.9275 - val_attrition_output_accuracy: 0.8776 - val_attrition_output_loss: 0.3567 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 0.8245 - val_loss: 1.1831
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.8837 - attrition_output_loss: 0.2931 - department_output_accuracy: 0.7283 - department_output_loss: 0.5995 - loss: 0.8926 - val_attrition_output_accuracy: 0.8571 - val_attrition_output_loss: 0.3678 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 0.8473 - val_loss: 1.2168
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8713 - attrition_output_loss: 0.2949 - department_output_accuracy: 0.7432 - department_output_loss: 0.5975 - loss: 0.8918 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3666 - val_department_output_accuracy: 0.6259 - val_department_output_loss: 0.8382 - val_loss: 1.2068
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.8910 - attrition_output_loss: 0.2932 - department_output_accuracy: 0.7402 - department_output_loss: 0.5815 - loss: 0.8743 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3661 - val_department_output_accuracy: 0.5816 - val_department_output_loss: 0.8642 - val_loss: 1.2322
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8702 - attrition_output_loss: 0.3189 - department_output_accuracy: 0.7489 - department_output_loss: 0.5752 - loss: 0.8945 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3664 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 0.8503 - val_loss: 1.2187
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8675 - attrition_output_loss: 0.3118 - department_output_accuracy: 0.7463 - department_output_loss: 0.5653 - loss: 0.8769 - val_attrition_output_accuracy: 0.8673 - val_attrition_output_loss: 0.3718 - val_department_output_accuracy: 0.6224 - val_department_output_loss: 0.8606 - val_loss: 1.2344
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8788 - attrition_output_loss: 0.2948 - department_output_accuracy: 0.7597 - department_output_loss: 0.5553 - loss: 0.8499 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3667 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 0.8770 - val_loss: 1.2459
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8739 - attrition_output_loss: 0.3072 - department_output_accuracy: 0.7615 - department_output_loss: 0.5638 - loss: 0.8713 - val_attrition_output_accuracy: 0.8776 - val_attrition_output_loss: 0.3745 - val_department_output_accuracy: 0.6259 - val_department_output_loss: 0.8716 - val_loss: 1.2481
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8807 - attrition_output_loss: 0.2946 - department_output_accuracy: 0.7734 - department_output_loss: 0.5392 - loss: 0.8338 - val_attrition_output_accuracy: 0.8639 - val_attrition_output_loss: 0.3801 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 0.8874 - val_loss: 1.2700
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8893 - attrition_output_loss: 0.2754 - department_output_accuracy: 0.7839 - department_output_loss: 0.5145 - loss: 0.7898 - val_attrition_output_accuracy: 0.8741 - val_attrition_output_loss: 0.3774 - val_department_output_accuracy: 0.6156 - val_department_output_loss: 0.8925 - val_loss: 1.2722
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8879 - attrition_output_loss: 0.2689 - department_output_accuracy: 0.7567 - department_output_loss: 0.5391 - loss: 0.8079 - val_attrition_output_accuracy: 0.8537 - val_attrition_output_loss: 0.3811 - val_department_output_accuracy: 0.6224 - val_department_output_loss: 0.8943 - val_loss: 1.2778
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9025 - attrition_output_loss: 0.2671 - department_output_accuracy: 0.7988 - department_output_loss: 0.5141 - loss: 0.7807 - val_attrition_output_accuracy: 0.8503 - val_attrition_output_loss: 0.3881 - val_department_output_accuracy: 0.6156 - val_department_output_loss: 0.9031 - val_loss: 1.2935
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8954 - attrition_output_loss: 0.2753 - department_output_accuracy: 0.8017 - department_output_loss: 0.4880 - loss: 0.7627 - val_attrition_output_accuracy: 0.8776 - val_attrition_output_loss: 0.3888 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 0.9081 - val_loss: 1.2996
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8933 - attrition_output_loss: 0.2638 - department_output_accuracy: 0.8042 - department_output_loss: 0.4846 - loss: 0.7485 - val_attrition_output_accuracy: 0.8537 - val_attrition_output_loss: 0.3914 - val_department_output_accuracy: 0.6395 - val_department_output_loss: 0.9129 - val_loss: 1.3066
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.8945 - attrition_output_loss: 0.2624 - department_output_accuracy: 0.8164 - department_output_loss: 0.4756 - loss: 0.7377 - val_attrition_output_accuracy: 0.8503 - val_attrition_output_loss: 0.3973 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 0.9301 - val_loss: 1.3300
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - attrition_output_accuracy: 0.8971 - attrition_output_loss: 0.2663 - department_output_accuracy: 0.8093 - department_output_loss: 0.4565 - loss: 0.7228 - val_attrition_output_accuracy: 0.8810 - val_attrition_output_loss: 0.3949 - val_department_output_accuracy: 0.6156 - val_department_output_loss: 0.9365 - val_loss: 1.3343
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - attrition_output_accuracy: 0.9066 - attrition_output_loss: 0.2381 - department_output_accuracy: 0.8381 - department_output_loss: 0.4563 - loss: 0.6944 - val_attrition_output_accuracy: 0.8503 - val_attrition_output_loss: 0.3987 - val_department_output_accuracy: 0.5986 - val_department_output_loss: 0.9546 - val_loss: 1.3561
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - attrition_output_accuracy: 0.9048 - attrition_output_loss: 0.2330 - department_output_accuracy: 0.8237 - department_output_loss: 0.4553 - loss: 0.6886 - val_attrition_output_accuracy: 0.8401 - val_attrition_output_loss: 0.4055 - val_department_output_accuracy: 0.6293 - val_department_output_loss: 0.9488 - val_loss: 1.3567
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - attrition_output_accuracy: 0.9111 - attrition_output_loss: 0.2400 - department_output_accuracy: 0.8249 - department_output_loss: 0.4434 - loss: 0.6836 - val_attrition_output_accuracy: 0.8639 - val_attrition_output_loss: 0.4008 - val_department_output_accuracy: 0.6327 - val_department_output_loss: 0.9685 - val_loss: 1.3721
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - attrition_output_accuracy: 0.9078 - attrition_output_loss: 0.2302 - department_output_accuracy: 0.8308 - department_output_loss: 0.4125 - loss: 0.6421 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.4115 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 0.9792 - val_loss: 1.3931
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - attrition_output_accuracy: 0.9100 - attrition_output_loss: 0.2272 - department_output_accuracy: 0.8523 - department_output_loss: 0.4123 - loss: 0.6395 - val_attrition_output_accuracy: 0.8503 - val_attrition_output_loss: 0.4108 - val_department_output_accuracy: 0.5918 - val_department_output_loss: 1.0151 - val_loss: 1.4290
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - attrition_output_accuracy: 0.9083 - attrition_output_loss: 0.2180 - department_output_accuracy: 0.8550 - department_output_loss: 0.3995 - loss: 0.6176 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.4188 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.0184 - val_loss: 1.4402
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - attrition_output_accuracy: 0.9066 - attrition_output_loss: 0.2312 - department_output_accuracy: 0.8583 - department_output_loss: 0.3924 - loss: 0.6233 - val_attrition_output_accuracy: 0.8469 - val_attrition_output_loss: 0.4238 - val_department_output_accuracy: 0.5850 - val_department_output_loss: 1.0435 - val_loss: 1.4704
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - attrition_output_accuracy: 0.8963 - attrition_output_loss: 0.2326 - department_output_accuracy: 0.8524 - department_output_loss: 0.3900 - loss: 0.6231 - val_attrition_output_accuracy: 0.8537 - val_attrition_output_loss: 0.4149 - val_department_output_accuracy: 0.6156 - val_department_output_loss: 1.0407 - val_loss: 1.4589
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9105 - attrition_output_loss: 0.2119 - department_output_accuracy: 0.8597 - department_output_loss: 0.3827 - loss: 0.5949 - val_attrition_output_accuracy: 0.8401 - val_attrition_output_loss: 0.4362 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.0556 - val_loss: 1.4949
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9148 - attrition_output_loss: 0.2023 - department_output_accuracy: 0.8750 - department_output_loss: 0.3429 - loss: 0.5451 - val_attrition_output_accuracy: 0.8605 - val_attrition_output_loss: 0.4323 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 1.0638 - val_loss: 1.4995
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - attrition_output_accuracy: 0.9093 - attrition_output_loss: 0.2063 - department_output_accuracy: 0.8852 - department_output_loss: 0.3367 - loss: 0.5428 - val_attrition_output_accuracy: 0.8503 - val_attrition_output_loss: 0.4323 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 1.0822 - val_loss: 1.5177
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9168 - attrition_output_loss: 0.1985 - department_output_accuracy: 0.8750 - department_output_loss: 0.3430 - loss: 0.5419 - val_attrition_output_accuracy: 0.8435 - val_attrition_output_loss: 0.4452 - val_department_output_accuracy: 0.6156 - val_department_output_loss: 1.0942 - val_loss: 1.5425
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9166 - attrition_output_loss: 0.1914 - department_output_accuracy: 0.8888 - department_output_loss: 0.3317 - loss: 0.5233 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.4547 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 1.1177 - val_loss: 1.5759
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9297 - attrition_output_loss: 0.1810 - department_output_accuracy: 0.8853 - department_output_loss: 0.3337 - loss: 0.5146 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.4629 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 1.1571 - val_loss: 1.6233
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9354 - attrition_output_loss: 0.1749 - department_output_accuracy: 0.9030 - department_output_loss: 0.3018 - loss: 0.4767 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.4645 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 1.1566 - val_loss: 1.6239
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9376 - attrition_output_loss: 0.1675 - department_output_accuracy: 0.8935 - department_output_loss: 0.3233 - loss: 0.4911 - val_attrition_output_accuracy: 0.8469 - val_attrition_output_loss: 0.4657 - val_department_output_accuracy: 0.6395 - val_department_output_loss: 1.1718 - val_loss: 1.6415
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9212 - attrition_output_loss: 0.1928 - department_output_accuracy: 0.9080 - department_output_loss: 0.2976 - loss: 0.4904 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.4766 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 1.2157 - val_loss: 1.6958
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - attrition_output_accuracy: 0.9456 - attrition_output_loss: 0.1635 - department_output_accuracy: 0.9040 - department_output_loss: 0.2917 - loss: 0.4553 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.4800 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 1.2101 - val_loss: 1.6941
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9349 - attrition_output_loss: 0.1588 - department_output_accuracy: 0.9089 - department_output_loss: 0.2865 - loss: 0.4453 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.4899 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.2485 - val_loss: 1.7421
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9415 - attrition_output_loss: 0.1600 - department_output_accuracy: 0.9035 - department_output_loss: 0.2685 - loss: 0.4284 - val_attrition_output_accuracy: 0.8435 - val_attrition_output_loss: 0.4992 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 1.2682 - val_loss: 1.7714
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9456 - attrition_output_loss: 0.1476 - department_output_accuracy: 0.9215 - department_output_loss: 0.2523 - loss: 0.3999 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.5051 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 1.2608 - val_loss: 1.7701
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9499 - attrition_output_loss: 0.1442 - department_output_accuracy: 0.9241 - department_output_loss: 0.2557 - loss: 0.4000 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.5182 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 1.3273 - val_loss: 1.8501
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9470 - attrition_output_loss: 0.1385 - department_output_accuracy: 0.9142 - department_output_loss: 0.2617 - loss: 0.4001 - val_attrition_output_accuracy: 0.8231 - val_attrition_output_loss: 0.5366 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 1.3234 - val_loss: 1.8642
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9531 - attrition_output_loss: 0.1396 - department_output_accuracy: 0.9225 - department_output_loss: 0.2410 - loss: 0.3805 - val_attrition_output_accuracy: 0.8231 - val_attrition_output_loss: 0.5233 - val_department_output_accuracy: 0.5986 - val_department_output_loss: 1.3684 - val_loss: 1.8963
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9522 - attrition_output_loss: 0.1360 - department_output_accuracy: 0.9489 - department_output_loss: 0.2159 - loss: 0.3517 - val_attrition_output_accuracy: 0.8197 - val_attrition_output_loss: 0.5412 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.3579 - val_loss: 1.9039
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9626 - attrition_output_loss: 0.1257 - department_output_accuracy: 0.9236 - department_output_loss: 0.2311 - loss: 0.3568 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.5442 - val_department_output_accuracy: 0.6395 - val_department_output_loss: 1.3793 - val_loss: 1.9287
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9622 - attrition_output_loss: 0.1253 - department_output_accuracy: 0.9311 - department_output_loss: 0.2211 - loss: 0.3461 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.5587 - val_department_output_accuracy: 0.6190 - val_department_output_loss: 1.4081 - val_loss: 1.9720
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9652 - attrition_output_loss: 0.1201 - department_output_accuracy: 0.9111 - department_output_loss: 0.2340 - loss: 0.3540 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.5627 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.4498 - val_loss: 2.0177
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9647 - attrition_output_loss: 0.1123 - department_output_accuracy: 0.9385 - department_output_loss: 0.2076 - loss: 0.3200 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.5736 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.4481 - val_loss: 2.0269
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9687 - attrition_output_loss: 0.1092 - department_output_accuracy: 0.9452 - department_output_loss: 0.1959 - loss: 0.3052 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.5853 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.4727 - val_loss: 2.0640
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9683 - attrition_output_loss: 0.0996 - department_output_accuracy: 0.9516 - department_output_loss: 0.1897 - loss: 0.2895 - val_attrition_output_accuracy: 0.8231 - val_attrition_output_loss: 0.5937 - val_department_output_accuracy: 0.6259 - val_department_output_loss: 1.5128 - val_loss: 2.1115
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9729 - attrition_output_loss: 0.0953 - department_output_accuracy: 0.9502 - department_output_loss: 0.1792 - loss: 0.2744 - val_attrition_output_accuracy: 0.8435 - val_attrition_output_loss: 0.5914 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.5481 - val_loss: 2.1456
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9689 - attrition_output_loss: 0.1008 - department_output_accuracy: 0.9568 - department_output_loss: 0.1726 - loss: 0.2733 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.6150 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 1.5495 - val_loss: 2.1712
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - attrition_output_accuracy: 0.9736 - attrition_output_loss: 0.0907 - department_output_accuracy: 0.9557 - department_output_loss: 0.1653 - loss: 0.2561 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.6126 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 1.6070 - val_loss: 2.2259
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9740 - attrition_output_loss: 0.0940 - department_output_accuracy: 0.9683 - department_output_loss: 0.1544 - loss: 0.2484 - val_attrition_output_accuracy: 0.8401 - val_attrition_output_loss: 0.6230 - val_department_output_accuracy: 0.5612 - val_department_output_loss: 1.6275 - val_loss: 2.2573
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9761 - attrition_output_loss: 0.0884 - department_output_accuracy: 0.9471 - department_output_loss: 0.1814 - loss: 0.2698 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.6380 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.6523 - val_loss: 2.2969
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9848 - attrition_output_loss: 0.0796 - department_output_accuracy: 0.9547 - department_output_loss: 0.1616 - loss: 0.2410 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.6430 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 1.6557 - val_loss: 2.3053
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9768 - attrition_output_loss: 0.0882 - department_output_accuracy: 0.9637 - department_output_loss: 0.1526 - loss: 0.2408 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.6659 - val_department_output_accuracy: 0.5816 - val_department_output_loss: 1.7413 - val_loss: 2.4139
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9801 - attrition_output_loss: 0.0754 - department_output_accuracy: 0.9582 - department_output_loss: 0.1553 - loss: 0.2306 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.6782 - val_department_output_accuracy: 0.5782 - val_department_output_loss: 1.6969 - val_loss: 2.3833
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9734 - attrition_output_loss: 0.0782 - department_output_accuracy: 0.9653 - department_output_loss: 0.1435 - loss: 0.2217 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.6860 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 1.7231 - val_loss: 2.4160
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9760 - attrition_output_loss: 0.0852 - department_output_accuracy: 0.9653 - department_output_loss: 0.1385 - loss: 0.2234 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.6896 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 1.7777 - val_loss: 2.4746
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9820 - attrition_output_loss: 0.0661 - department_output_accuracy: 0.9755 - department_output_loss: 0.1306 - loss: 0.1965 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.6942 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 1.7790 - val_loss: 2.4802
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9826 - attrition_output_loss: 0.0729 - department_output_accuracy: 0.9725 - department_output_loss: 0.1258 - loss: 0.1987 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.6897 - val_department_output_accuracy: 0.5748 - val_department_output_loss: 1.8049 - val_loss: 2.5026
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9823 - attrition_output_loss: 0.0669 - department_output_accuracy: 0.9701 - department_output_loss: 0.1285 - loss: 0.1953 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.7170 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.8452 - val_loss: 2.5698
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9852 - attrition_output_loss: 0.0634 - department_output_accuracy: 0.9746 - department_output_loss: 0.1192 - loss: 0.1827 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.7306 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.8353 - val_loss: 2.5736
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9868 - attrition_output_loss: 0.0642 - department_output_accuracy: 0.9726 - department_output_loss: 0.1175 - loss: 0.1818 - val_attrition_output_accuracy: 0.8401 - val_attrition_output_loss: 0.7354 - val_department_output_accuracy: 0.5986 - val_department_output_loss: 1.8778 - val_loss: 2.6213
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9822 - attrition_output_loss: 0.0712 - department_output_accuracy: 0.9770 - department_output_loss: 0.1089 - loss: 0.1802 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.7449 - val_department_output_accuracy: 0.5850 - val_department_output_loss: 1.9159 - val_loss: 2.6688
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9859 - attrition_output_loss: 0.0582 - department_output_accuracy: 0.9837 - department_output_loss: 0.1064 - loss: 0.1645 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.7481 - val_department_output_accuracy: 0.5748 - val_department_output_loss: 1.9579 - val_loss: 2.7144
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9818 - attrition_output_loss: 0.0593 - department_output_accuracy: 0.9682 - department_output_loss: 0.1117 - loss: 0.1709 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.7882 - val_department_output_accuracy: 0.6122 - val_department_output_loss: 1.9745 - val_loss: 2.7716
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9894 - attrition_output_loss: 0.0521 - department_output_accuracy: 0.9787 - department_output_loss: 0.1140 - loss: 0.1660 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.7694 - val_department_output_accuracy: 0.5918 - val_department_output_loss: 2.0161 - val_loss: 2.7928
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9865 - attrition_output_loss: 0.0559 - department_output_accuracy: 0.9831 - department_output_loss: 0.0924 - loss: 0.1483 - val_attrition_output_accuracy: 0.8435 - val_attrition_output_loss: 0.7816 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 1.9902 - val_loss: 2.7798
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9934 - attrition_output_loss: 0.0521 - department_output_accuracy: 0.9826 - department_output_loss: 0.1030 - loss: 0.1551 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.7911 - val_department_output_accuracy: 0.5918 - val_department_output_loss: 2.0371 - val_loss: 2.8376
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9845 - attrition_output_loss: 0.0491 - department_output_accuracy: 0.9818 - department_output_loss: 0.1010 - loss: 0.1501 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.8010 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 2.0521 - val_loss: 2.8622
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9940 - attrition_output_loss: 0.0433 - department_output_accuracy: 0.9857 - department_output_loss: 0.0847 - loss: 0.1279 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.8140 - val_department_output_accuracy: 0.5782 - val_department_output_loss: 2.1194 - val_loss: 2.9412
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - attrition_output_accuracy: 0.9943 - attrition_output_loss: 0.0425 - department_output_accuracy: 0.9905 - department_output_loss: 0.0807 - loss: 0.1233 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.8250 - val_department_output_accuracy: 0.6054 - val_department_output_loss: 2.1070 - val_loss: 2.9415
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9946 - attrition_output_loss: 0.0413 - department_output_accuracy: 0.9900 - department_output_loss: 0.0716 - loss: 0.1129 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.8493 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 2.1270 - val_loss: 2.9861
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9953 - attrition_output_loss: 0.0376 - department_output_accuracy: 0.9952 - department_output_loss: 0.0705 - loss: 0.1081 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.8483 - val_department_output_accuracy: 0.5884 - val_department_output_loss: 2.1628 - val_loss: 3.0206
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9966 - attrition_output_loss: 0.0385 - department_output_accuracy: 0.9935 - department_output_loss: 0.0685 - loss: 0.1070 - val_attrition_output_accuracy: 0.8129 - val_attrition_output_loss: 0.8771 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 2.1690 - val_loss: 3.0556
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - attrition_output_accuracy: 0.9950 - attrition_output_loss: 0.0390 - department_output_accuracy: 0.9942 - department_output_loss: 0.0719 - loss: 0.1109 - val_attrition_output_accuracy: 0.8333 - val_attrition_output_loss: 0.8707 - val_department_output_accuracy: 0.6088 - val_department_output_loss: 2.2526 - val_loss: 3.1329
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9958 - attrition_output_loss: 0.0394 - department_output_accuracy: 0.9856 - department_output_loss: 0.0830 - loss: 0.1223 - val_attrition_output_accuracy: 0.8231 - val_attrition_output_loss: 0.8633 - val_department_output_accuracy: 0.6020 - val_department_output_loss: 2.2192 - val_loss: 3.0928
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.9978 - attrition_output_loss: 0.0351 - department_output_accuracy: 0.9955 - department_output_loss: 0.0655 - loss: 0.1004 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.8936 - val_department_output_accuracy: 0.5918 - val_department_output_loss: 2.2820 - val_loss: 3.1856
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9979 - attrition_output_loss: 0.0364 - department_output_accuracy: 0.9944 - department_output_loss: 0.0632 - loss: 0.0995 - val_attrition_output_accuracy: 0.8265 - val_attrition_output_loss: 0.8958 - val_department_output_accuracy: 0.5850 - val_department_output_loss: 2.3114 - val_loss: 3.2182
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9932 - attrition_output_loss: 0.0371 - department_output_accuracy: 0.9957 - department_output_loss: 0.0622 - loss: 0.0994 - val_attrition_output_accuracy: 0.8367 - val_attrition_output_loss: 0.9018 - val_department_output_accuracy: 0.5952 - val_department_output_loss: 2.3232 - val_loss: 3.2355
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - attrition_output_accuracy: 0.9933 - attrition_output_loss: 0.0341 - department_output_accuracy: 0.9961 - department_output_loss: 0.0533 - loss: 0.0874 - val_attrition_output_accuracy: 0.8299 - val_attrition_output_loss: 0.9180 - val_department_output_accuracy: 0.5850 - val_department_output_loss: 2.3563 - val_loss: 3.2852

# %%
# Evaluate the model with the testing data
evaluation = model.evaluate(X_test_scaled,
                            {'department_output': y_test_encoded, 'attrition_output': y_test_attrition_encoded},
                             verbose=1)

#print the evaluation results
print(f"Test Accuracy: {evaluation[3]}")

#extract the specific loss and accuracy values
loss = evaluation[0]
department_loss = evaluation[1]
attrition_loss = evaluation[2]
department_accuracy = evaluation[3]
attrition_accuracy = evaluation[4]

print(f"Loss: {loss}, Department Loss: {department_loss}, Attrition Loss: {attrition_loss}")
print(f"Department Accuracy: {department_accuracy}, Attrition Accuracy: {attrition_accuracy}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8127 - attrition_output_loss: 1.1132 - department_output_accuracy: 0.5611 - department_output_loss: 2.6690 - loss: 3.8266
# Test Accuracy: 0.8299319744110107
# Loss: 3.2851855754852295, Department Loss: 2.1863272190093994, Attrition Loss: 0.8546551465988159
# Department Accuracy: 0.8299319744110107, Attrition Accuracy: 0.5850340127944946

# %%
# Print the accuracy for both department and attrition
department_prediction = model.predict(X_test_scaled)[0]
department_accuracy = np.mean(np.argmax(y_test_encoded, axis=1) == np.argmax(department_prediction, axis=1))
print(f"Department Accuracy: {department_accuracy}")

attrition_prediction = model.predict(X_test_scaled)[1]
attrition_accuracy = np.mean(np.argmax(y_test_attrition_encoded, axis=1) == np.argmax(attrition_prediction, axis=1))
print(f"Attrition Accuracy: {attrition_accuracy}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Department Accuracy: 0.5850340136054422
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Attrition Accuracy: 0.8299319727891157

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# Model Evaluation and Improvement
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#     * No,  accuracy is not the most reliable metric because it doesn't address class imbalances. For instance, if the number of employees who leave the company (attrition) is significantly lower than those who stay, accuracy can be deceptive. Metrics like precision, recall, and F1-score offer better insights into the model's performance, particularly for minority classes. These metrics take into account true positives, false positives, and false negatives, providing a more comprehensive evaluation of the model's effectiveness.
# 2. What activation functions did you choose for your output layers, and why?
#     * Softmax is applied to both department_output and attrition_output. For department_output, it handles multi-class classification by ensuring the outputs sum to 1, representing probabilities for each class. For attrition_output, despite being a binary classification, softmax is used to obtain probabilities for each class (Yes/No). This helps interpret the outputs as the likelihood of each class, aiding in better decision-making based on predicted probabilities.
# 3. Can you name a few ways that this model might be improved?
#     * Expand Data Collection: Gather more training data to enhance the model's ability to generalize. This can include accumulating additional employee data over time or sourcing it from various channels.
#     * Enhance Features: Improve input data by adding or modifying features. For example, create new metrics like the ratio of total working years to years at the company, or represent tenure in months instead of years.
#     * Optimize Hyperparameters: Fine-tune parameters such as learning rates, batch sizes, and the number of neurons/layers. Experiment with different settings to identify the optimal combination for better model performance.
#     * Apply Regularization: Use techniques like dropout or L2 regularization to avoid overfitting. Dropout randomly excludes some neurons during training to increase robustness, while L2 regularization imposes a penalty on large weights.
